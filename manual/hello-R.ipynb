# %% [markdown]
# # Mohammad's Hello World R Notebook

# %% [markdown]
# ## This is my second Jupyter Notebook

# %% [markdown]
# Just doing my *assignment*

# %%
print("Hello World")
# Out:
# Hello World
